# %% [markdown]
# <a href="https://colab.research.google.com/github/MANOJ-S-NEGI/C_lang/blob/main/Try_throw_exception.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Assignment – 30 [ Exception Handling ]**
# ---
# ---
#
# 1. Write a C++ program to demonstrate the use of try, catch block with the argument as an integer and string using multiple catch blocks.
#
# ```
# #include<iostream>
# using namespace std;
# #include <string>
#
# class A
#     {
#         private:
#             int a;
#             string* b;
#         public:
#
#             A()
#                 {
#                     a = -1;
#                     b = nullptr;
#                 }
#
#             void _set(int a, string b)
#                 {
#                     try
#                         {
#                             if(a<0)
#                                 {
#                                     throw("Entered number less than 0, called default value: " ,a);
#                                 }
#                             if(b.empty())
#                                 {
#                                     throw "String cannot be empty";
#                                 }
#
#                             this->a = a;
#                             this->b = new string(b);
#                         }
#
#                     catch(const int e)
#                         {
#                             cout << "Exception caught:" << e << endl;
#                         }
#
#                     catch(const char* errorMessage)
#                         {
#                             cout << "Exception caught: " << errorMessage << endl;
#                         }
#
#                 }
#              void display()
#                 {
#                     cout << "Result: Integer = " << a << ", String = " << *b << endl;
#                 }
#
#              ~A()
#                 {
#                     delete b;
#                 }
#     };
#
# int main()
#     {
#         cout<< "Required two arguments :- "<<endl;
#         int x;
#         string y;
#         cout<< "Enter First argument as number: ";
#         cin >> x;
#         cout<< endl << "Enter Second argument as string: ";
#         cin >> y;
#         cin.ignore();
#         getline(cin, y);
#         cout<< endl ;
#
#         A obj;
#         obj._set(x, y);
#         obj.display();
#         return 0;
#     }
#
#
# ```
#
# ---
# ---
#
# 2. Write a C++ program to demonstrate try, throw and catch statements.
#
#
# ```
# #include<iostream>
# using namespace std;
#
# class A
#     {
#         private:
#             int c;
#
#         public:
#             void _set(int a, int b)
#                 {
#                     try
#                         {
#                             if(b==0)
#                                 {
#                                     throw("Entered denominator is 0, division Error!");
#                                 }
#                             c = a/b;
#                         }
#
#                     catch(const char* errorMessage)
#                         {
#                             cout << "Exception caught: " << errorMessage << endl;
#                         }
#                 }
#
#              void display()
#                 {
#                     cout << "Result: " << c << endl;
#                 }
#     };
#
# int main()
#     {
#         cout<< "Required two numbers :- "<<endl;
#         int x, y;
#         cout<< "Enter First number: ";
#         cin >> x;
#         cout<< endl << "Enter Second number: ";
#         cin >> y;
#         cout<< endl ;
#         A obj;
#        obj._set(x, y);
#        obj.display();
#        return 0;
#     }
# ```
#
# ---
# ---
#
# 3. Write a C++ program to perform arithmetic operations on two numbers and throw an exception if the dividend is zero or does not contain an operator.
#
# ```
# #include<iostream>
# using namespace std;
#
# class A
#     {
#         private:
#             int c;
#
#         public:
#             void _set(int a, int b)
#                 {
#                     try
#                         {
#                             if(b==0)
#                                 {
#                                     throw("Entered denominator is 0, division Error!");
#                                 }
#                             c = a/b;
#                         }
#
#                     catch(const char* errorMessage)
#                         {
#                             cout << "Exception caught: " << errorMessage << endl;
#                         }
#                 }
#
#              void display()
#                 {
#                     cout << "Result: " << c << endl;
#                 }
#     };
#
# int main()
#     {
#         cout<< "Required two numbers :- "<<endl;
#         int x, y;
#         cout<< "Enter First number: ";
#         cin >> x;
#         cout<< endl << "Enter Second number: ";
#         cin >> y;
#         cout<< endl ;
#         A obj;
#        obj._set(x, y);
#        obj.display();
#        return 0;
#     }
#
# ```
#
# ---
# ---
#
# 4. Write a C++ program to accept an email address and throw an exception if it does not contain @ symbol.
#
# ```
# //4. Write a C++ program to accept an email address and throw an exception if it does not contain @ symbol.
#
# #include<iostream>
# using namespace std;
#
# class A
#     {
#         private:
#             string* s;
#
#         public:
#             A()
#                {
#                     s = nullptr;
#                }
#
#             void _set(string email)
#                 {
#                     try
#                         {
#                             if (email.find('@') == string::npos)
#                                 {
#                                     throw("Email not contain @, invalid email_id");
#                                 }
#                              else
#                                 {
#                                     cout<< "valid email";
#                                 }
#
#                         }
#
#                     catch (const char* errorMessage)
#                         {
#                             cout << "Exception caught: " << errorMessage << endl;
#                         }
#                 }
#
#              ~A()
#                 {
#                     delete s;
#                 }
#
#     };
#
# int main()
#  {
#     string email;
#     cout << "Enter your email address: ";
#     cin.ignore();
#     getline(cin, email);
#
#     A obj;
#     obj._set(email);
#     return 0;
# }
#
#
# ```
#
# ---
# ---
#
#
# 5. Write a C++ program to accept a mobile number and throw an exception if it does not contain 10 digits.
#
# ```
# //4. Write a C++ program to accept an email address and throw an exception if it does not contain @ symbol.
#
# #include<iostream>
# using namespace std;
#
# class mobile
#     {
#         private:
#
#         public:
#             int count=0;
#             void _set()
#                 {
#                  try
#                     {
#                         int num;
#                         cout<<"Enter 10 digit Mobile number :";
#                         cin >>num;
#                         for(int i=num; i>0;i/=10)
#                             {
#                                 //cout<<i<<endl;
#                                 count++;
#                             }
#                         if(count!=10)
#                             {
#                                 throw("Invalid Number! enter 10 digit mobile number");
#                             }
#                           else
#                             {
#                                 cout<<"Mobile number is valid: "<< num;
#                             }
#                     }
#                  catch(const char* error_msg)
#                     {
#                       cout << "Exception caught: " << error_msg << endl;
#                     }
#                 }
#          };
#
# int main()
#  {
#     mobile number;
#     number._set();
#     return 0;
# }
#
#
# ```
# ---
# ---
#
#
# 6. Write a C++ program to accept area pin code and throw an exception if it does not contain 6 digits.
#
# ```
# //4. Write a C++ program to accept an email address and throw an exception if it does not contain @ symbol.
#
# #include<iostream>
# using namespace std;
#
# class Pin
#     {
#         private:
#
#         public:
#             int count=0;
#             void _set()
#                 {
#                  try
#                     {
#                         int num;
#                         cout<<"Enter pin code :";
#                         cin >>num;
#                         for(int i=num; i>0;i/=10)
#                             {
#                                 //cout<<i<<endl;
#                                 count++;
#                             }
#                         if(count!=6)
#                             {
#                                 throw("Invalid Pin ! enter 6 digit Pin number");
#                             }
#                           else
#                             {
#                                 cout<<"Pin number is valid: "<< num;
#                             }
#                     }
#                  catch(const char* error_msg)
#                     {
#                       cout << "Exception caught: " << error_msg << endl;
#                     }
#                 }
#          };
#
# int main()
#  {
#     Pin number;
#     number._set();
#     return 0;
# }
#
#
# ```
# ---
# ---
#
# 7. Write a C++ program to accept a username if the username has less than 6 characters or does contain any digit or special symbol.
#
# ```
# #include<iostream>
# using namespace std;
# #include<cstring>
# class Username
# {
#     private:
#         char* nicname;
#         int size;
#
#     public:
#         Username()
#             {
#                 nicname = nullptr;
#                 size = 20;
#             }
#         ~Username()
#             {
#                 if(nicname)
#                     {
#                         free(nicname);
#                     }
#             }
#
#            void _set()
#                 {
#                     try
#                         {
#                             nicname = (char*)malloc(size* sizeof(char));
#                             if (nicname == nullptr)
#                                 {
#                                     cout << "Memory allocation failed!" << endl;
#                                     return;
#                                 }
#                              cout<< "Enter Username up to 19 characters: ";
#
#                             cin.getline(nicname, size);
#
#                             if (strlen(nicname) > 6)
#                                 {
#                                     for(int i= 0; nicname[i]!='\0'; i++)
#                                         {
#                                             if (isdigit(nicname[i]) || ispunct(nicname[i]))
#                                                 {
#                                                     throw("Invalid user ! digits and symbol are not allowed ");
#                                                 }
#                                             else
#                                                 {
#                                                     cout<<nicname[i];
#
#                                                 }
#                                         }
#                                     cout<< "input user name accepted";
#                                  }
#                           else
#                             {
#                                 throw("Invalid username ! It must have length more than 6 ");
#                             }
#                     }
#                 catch(const char* error_msg)
#                     {
#                         cout << "Exception caught: " << error_msg << endl;
#                     }
#              }
# };
#
#
# int main()
# {
#     Username u;
#     u._set();
#     return 0;
# }
#
#
#
# ```
# ---
# ---
#
#
# 8. Write a C++ program to accept a password and throw an exception if the password has less than 6 characters or does not contain a digit or does not contain any special character or does not contain any capital letter.
#
# ```
# #include<iostream>
# using namespace std;
# #include<cstring>
# class Password
# {
#     private:
#         char* passcode;
#         int size;
#
#     public:
#         Password()
#             {
#                 passcode = nullptr;
#                 size = 30;
#             }
#         ~Password()
#             {
#                 if(passcode)
#                     {
#                         free(passcode);
#                     }
#             }
#
#            void _set()
#                 {
#                     try
#                         {
#                             passcode = (char*)malloc(size* sizeof(char));
#                             if (passcode == nullptr)
#                                 {
#                                     cout << "Memory allocation failed!" << endl;
#                                     return;
#                                 }
#                              cout<< "Enter passcode: ";
#
#                             cin.getline(passcode, size);
#
#                             if (strlen(passcode) > 6)
#                                 {
#                                     for(int i= 0; passcode[i]!='\0'; i++)
#                                         {
#                                             if (isdigit(passcode[i]) || ispunct(passcode[i]) || isupper(passcode[i]))
#                                                 {
#                                                     throw("Invalid password ! digits and symbol are not allowed ");
#                                                 }
#                                             else
#                                                 {
#                                                     cout<<passcode[i];
#                                                 }
#                                         }
#                                      cout<< endl<<"password accepted";
#                                  }
#                           else
#                             {
#                                 throw("Invalid Password ! It must have length more than 6 ");
#                             }
#                     }
#                 catch(const char* error_msg)
#                     {
#                         cout << "Exception caught: " << error_msg << endl;
#                     }
#              }
# };
#
# int main()
# {
#     Password u;
#     u._set();
#     return 0;
# }
#
#
#
# ```
# ---
# ---
#
#
# 9. Write a C++ program to accept Gmail id only and throw an exception if the id does not contain @ and gmail.com.
#
# ```
# #include<iostream>
# using namespace std;
#
# class Gmail
# {
#     private:
#         string mail;
#
#     public:
#         void setmail()
#             {
#                 try
#                     {
#                         cout<< "Enter your gmail :";
#                         getline(cin, mail);
#                         if (mail.find('@') != string::npos ||  mail.find("gmail.com") != string::npos)
#                             {
#                                 cout<<endl<< "email address is vaild";
#                             }
#                          else
#                             {
#                                 throw("Email Invalid ! ");
#                             }
#                     }
#                 catch(const char* error_msg)
#                     {
#                         cout<< "exception caught: "<< error_msg<<endl;
#                     }
#             }
# };
#
# int main()
# {
#     Gmail g;
#     g.setmail();
#     return 0;
# }
#
#
# ```
#
# ---
# ---
#
# 10. Write a C++ program to accept Nickname and throw an exception if it has greater than 8 characters or does contain a digit or special symbol or space.
#
# ```
# #include<iostream>
# #include <cstring>
# using namespace std;
#
# class Nickname
#     {
#         private:
#             char nick[20];
#
#         public:
#
#             void logic_call()
#                 {
#                     try
#                         {
#                             cout << "Enter your nickname: ";
#                             cin.getline(nick, 20);
#                             int length = strlen(nick);
#                             if (length > 8)
#                                 {
#                                     throw "Nickname is too long! It must not exceed 8 characters.";
#                                 }
#                             else
#                                 {
#                                     for(int i=0; nick[i] !='\0'; i++)
#                                         {
#                                             if( isdigit(nick[i]) || ispunct(nick[i])|| isspace(nick[i]))
#                                                 {
#                                                     throw("Nickname is not valid! Remove space digits and punctuation");
#                                                 }
#                                          }
#                                      cout<<  "user accepted: " <<nick ;
#                                   }
#                           }
#                     catch(const char*  error_message)
#                         {
#                             cout << "Exception caught:  "<< error_message;
#                         }
#
#                 }
#
#
#     };
#
# int main()
# {
#     Nickname n;
#     n.logic_call();
#     return 0;
#
# }
#
#
# ```
#
# ---
# ---
